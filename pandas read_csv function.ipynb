# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\Paython\\Book1.csv')
print(df)
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df1=pd.read_csv('D:\\Paython\\Book1.csv', header=1)
print(df1)
# Out:
#     1/9/2022  yes  asim     13    1    123  34
# 0   1/2/2019  yes  zain  143.0  2.0  345.0  23
# 1   4/6/2019   no   NaN    NaN  3.0    NaN   2
# 2  4/11/2022  yes   NaN    NaN  NaN  345.0   3
# 3  2/10/2021   no  zaib  156.0  NaN  987.0  45
# 4   6/3/2022  yes  asif    NaN  NaN    NaN   6
# 5   2/4/2022  NaN   NaN   12.0  7.0    NaN   7

# %%
df.head()
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45

# %%
df.head(2)
# Out:
#        date  abc  name   roll   id    med  customer
# 0  1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1  1/2/2019  yes  zain  143.0  2.0  345.0        23

# %%
df.tail()
# Out:
#         date  abc  name   roll   id    med  customer
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df.tail(2)
# Out:
#        date  abc  name  roll   id  med  customer
# 5  6/3/2022  yes  asif   NaN  NaN  NaN         6
# 6  2/4/2022  NaN   NaN  12.0  7.0  NaN         7

# %%
df
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df=pd.read_csv('D:\\Paython\\Book1.csv',dtype=({'roll':'float64', 'id':'float64' }))
print(df)
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df=pd.read_csv('D:\\Paython\\Book1.csv', true_values=['yes'])
print(df)
# Out:
#         date  abc  name   roll   id    med  customer
# 0   1/9/2022  yes  asim   13.0  1.0  123.0        34
# 1   1/2/2019  yes  zain  143.0  2.0  345.0        23
# 2   4/6/2019   no   NaN    NaN  3.0    NaN         2
# 3  4/11/2022  yes   NaN    NaN  NaN  345.0         3
# 4  2/10/2021   no  zaib  156.0  NaN  987.0        45
# 5   6/3/2022  yes  asif    NaN  NaN    NaN         6
# 6   2/4/2022  NaN   NaN   12.0  7.0    NaN         7

# %%
df=pd.read_csv('D:\\Paython\\Book1.csv', true_values=['yes'], false_values=['no'])
print(df)
# Out:
#         date    abc  name   roll   id    med  customer
# 0   1/9/2022   True  asim   13.0  1.0  123.0        34
# 1   1/2/2019   True  zain  143.0  2.0  345.0        23
# 2   4/6/2019  False   NaN    NaN  3.0    NaN         2
# 3  4/11/2022   True   NaN    NaN  NaN  345.0         3
# 4  2/10/2021  False  zaib  156.0  NaN  987.0        45
# 5   6/3/2022   True  asif    NaN  NaN    NaN         6
# 6   2/4/2022    NaN   NaN   12.0  7.0    NaN         7
